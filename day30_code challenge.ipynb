# %%
#sting challenge
def length_of_longest_substring(s):
  chars = set()
  left=0
  max_len =0
  for right in range(len(s)):
    while s[right] in chars:
      chars.remove(s[left])
      left +=1
      chars.add(s[right])
      max_len= max(max_len,right - left +1)
      return max_len

      print(length_of_longest_subtring("abcabcbb"))
      print(length_of_longest_substring)

# %%
ages =[20,30,54,30,62]
uniqe = list(set(ages))
print(uniqe)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4202/694212619.py in <cell line: 0>()
#       1 ages =[20,30,54,30,62]
# ----> 2 uniqe = list(set(ages))
#       3 print(uniqe)
#
# TypeError: 'list' object is not callable

# %%
#tuple
values =( 10,5,20,8)
max_v= max(values)
print(max_v)
min_v= min(values)
print(min_v)
# Out:
# 20
# 5

# %%
#Dictionary
input="programming"
freq={}
for char in input:
  if char in freq:
    freq[char] +=1

# %%
#length
words = ["cat","dog","elephant","bat","tiger"]
grouped = {}

for animal in words:
    length = len(animal)
    if length not in grouped:
      grouped[length] = []
      grouped[length].append(animal)
